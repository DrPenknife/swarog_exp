# %%
# !pip3 install flair --quiet
# Out:
# WARNING: You are using pip version 21.3.1; however, version 22.2.2 is available.
# You should consider upgrading via the '/home/rkozik/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
from sklearn.model_selection import RepeatedStratifiedKFold

data = pd.read_csv("raw/covid_fake_news.csv",sep="\t")
data["label"] = 1- data["label"]
print("labels\n",data["label"].value_counts())
print("shape  \n",data.shape)

bootstrap_size = 0

if bootstrap_size != 0:
    bootstrap_factor = bootstrap_size / data.shape[0]
    bootstrap = np.random.uniform(size=data.shape[0]) < bootstrap_factor
    data = data.iloc[bootstrap]

X, y = data["title"].values, data["label"].values


rskf = RepeatedStratifiedKFold(n_splits=2, n_repeats=5, random_state=1410)
foldids = []
for fold_idx, (train, test) in tqdm(enumerate(rskf.split(X, y)), total=rskf.get_n_splits()):
    foldids.append((fold_idx,train,test))
    
print("shapes X",X.shape,"y", y.shape)
# Out:
# labels
#  1    8511
# 0     461
# Name: label, dtype: int64
# shape
#  (8972, 2)
# 100%|█████████████████████████████████████████| 10/10 [00:00<00:00, 2304.94it/s]
# shapes X (8972,) y (8972,)

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
from sklearn.model_selection import RepeatedStratifiedKFold

data = pd.read_csv("raw/pubhealth.csv",sep=",")
print("labels\n",data["label"].value_counts())
print("shape  \n",data.shape)

bootstrap_size = 0

if bootstrap_size != 0:
    bootstrap_factor = bootstrap_size / data.shape[0]
    bootstrap = np.random.uniform(size=data.shape[0]) < bootstrap_factor
    data = data.iloc[bootstrap]

X, y = data["text"].values, data["label"].values

rskf = RepeatedStratifiedKFold(n_splits=2, n_repeats=5, random_state=1410)
foldids = []
for fold_idx, (train, test) in tqdm(enumerate(rskf.split(X, y)), total=rskf.get_n_splits()):
    foldids.append((fold_idx,train,test))
    
print("shapes X",X.shape,"y", y.shape)
# Out:
# labels
#  1    6306
# 0    3769
# Name: label, dtype: int64
# shape
#  (10075, 11)
# 100%|█████████████████████████████████████████| 10/10 [00:00<00:00, 1794.12it/s]
# shapes X (10075,) y (10075,)

# %%
from flair.models import TARSClassifier
from flair.data import Sentence

import flair, torch
flair.device = torch.device('cuda')

# 1. Load our pre-trained TARS model for English
tars = TARSClassifier.load('tars-base')
# Out:
# 2022-09-24 08:39:34,934 loading file /home/rkozik/.flair/models/tars-base-v8.pt

# %%
# 2. Prepare a test sentence
sentence = Sentence("the student fell ill with covid")

# 3. Define some classes that you want to predict using descriptive names
classes = ["Health, Medicine",
           "Entertainment, Art, Culture", 
           "Computers, Science, Technology", 
           "Finance","Economics",
           "Lifestyle",
           "Sport, Leisure",
           "Politics",
           "Opinion, Recommendation, Review",
           "Traveling"
          ]

#4. Predict for these classes
tars.predict_zero_shot(sentence, classes)

# Print sentence with predicted labels
print(sentence)
# Out:
# Sentence: "the student fell ill with covid"   [− Tokens: 6  − Sentence-Labels: {'Health, Medicine-Entertainment, Art, Culture-Computers, Science, Technology-Finance-Economics-Lifestyle-Sport, Leisure-Politics-Opinion, Recommendation, Review-Traveling': [Health, Medicine (0.7386)]}]

# %%
sentence = Sentence(X[8])
tars.predict_zero_shot(sentence, classes)

import numpy as np
def get_best_lab(sentence):
    labels = sentence.to_dict()["labels"]
    if len(labels) > 0:
        return labels[np.argmax([x["confidence"] for x in labels])]["value"]
    else:
        return "none"

print(sentence,get_best_lab(sentence))
# Out:
# Sentence: "Social media posts criticize a photo from smiling president of the Goverment Pedro SÃ ¡ nchez during his holidays after thousands died from COVID-19"   [− Tokens: 24  − Sentence-Labels: {'Health, Medicine-Entertainment, Art, Culture-Computers, Science, Technology-Finance, Economics-Lifestyle-Sport, Leisure-Politics-Opinion, Recommendation, Review-Traveling': [Politics (0.8274)]}] Politics

# %%
classes = ["Health", "Medicine", "vaccination cure","virus",
           "Entertainment, Art, Culture", 
           "Computers, Science, Technology", 
           "Finance","Economics","Economy",
           "Lifestyle",
           "Sport, Leisure",
           "Politics",
           "Opinion, Recommendation, Review",
           "Traveling","pandemic","Government"
          ]

#classes = ["happy", "sad", "neutral"]



tt='Photo shows Muslims in Tamil Nadu state of India are floating lockdown rules during Ramzan to offer night prayer'
sentence = Sentence(tt)
tars.predict_zero_shot(sentence, classes)
print(sentence)
# Out:
# Sentence: "Photo shows Muslims in Tamil Nadu state of India are floating lockdown rules during Ramzan to offer night prayer"   [− Tokens: 19]

# %%
from tqdm import tqdm
from flair.datasets import DataLoader 

categories = []
sX = [Sentence(x) for x in tqdm(X)]

dataloader = DataLoader(sX, batch_size=32, num_workers=8)
for batch in tqdm(dataloader):
    tars.predict_zero_shot(batch, classes)

for s in tqdm(sX):
    c = get_best_lab(s)
    categories.append(c)
#    c = get_best_lab(s)
#    categories.append(c)
# Out:
# 100%|████████████████████████████████████| 10075/10075 [01:25<00:00, 118.33it/s]
#  78%|███████████████████████████████▉         | 245/315 [32:54<10:11,  8.74s/it]

# %%
import pickle
# SAVE
with open('covid_fake_news_categories.pickle', 'wb') as handle:
    pickle.dump(categories, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
oo=np.unique(categories, return_counts=True)
list(zip(oo[0],oo[1]))
# Out:
# [('Computers, Science, Technology', 454),
#  ('Economics', 82),
#  ('Economy', 82),
#  ('Entertainment, Art, Culture', 69),
#  ('Finance', 1),
#  ('Government', 1635),
#  ('Health', 438),
#  ('Medicine', 2357),
#  ('Opinion, Recommendation, Review', 2),
#  ('Politics', 839),
#  ('Sport, Leisure', 55),
#  ('Traveling', 91),
#  ('none', 902),
#  ('pandemic', 297),
#  ('vaccination cure', 1236),
#  ('virus', 432)]

# %%
X[np.where(np.array(categories) == 'none')]
# Out:
# array(['A photo claims that this person is a doctor who died after attending to too many COVID-19 patinents in Hospital MuÃ±iz in Buenos Aires.',
#        'Post about a video claims that it is a protest against confination in the town of Aranda de Duero (Burgos)',
#        'A picture shows hydroxychloroquine is being sold on public trains in Rio de Janeiro',
#        'COVID-19 is being controlled in Africa because of widespread distribution of ivermectin',
#        'A photo shows hand sanitizer being sold in a vitamin D box',
#        'There was a 78% fall on Chinese product sales in Brazil due to a boycott motivated by the pandemic, acording to INCINT',
#        'Adidas is giving away face masks.',
#        'An image published by the Argentine journalist Viviana Canosa of two people not respecting social distancing at the Casa Rosada',
#        'Lojas Americanas, a Brazilian retail company, is offering free gift cards for families in distress caused by the pandemic',
#        'A photo of man with swollen face shows side effect of CoronaVac in Brazilian volunteer',
#        'A post claimed that photos of a man in a gold mask are of a religious leader who â€œasked his congregation for a gold mask because God revealed it to him in a dream.â€\x9d',
#        'Thereâ€™s chloroquine and ivermectine on lemon and orange peels',
#        'COVID-19 Means â€˜See A Sheep Surrenderâ€™ In Latin',
#        'A ship carrying Honduran mobile hospitals caught fire',
#        'A post uses an image of an â€œundocumented Nicaraguanâ€\x9d and claims he tested positive for COVID-19, and is â€œspitting on doorsâ€\x9d',
#        'BoyacÃ¡ scientist says he can cure patients with COVID-19 through biology.',
#        'A post that indicates that Spanish doctors say that face masks donâ€™t work outdoors.',
#        'Brazil recorded more deaths in the first half of 2019 than in the first half of 2020.',
#        'Uruguay gave 55,000 doses of medecine for Brazil to fight COVID-19.',
#        'Multiple Facebook posts shared tens of thousands of times claim the novel coronavirus, which causes the disease COVID-19, has infected far fewer people than the H1N1 virus, or swine flu, but â€œmedia hysteriaâ€\x9d has prompted an overblown response.',
#        'French doctors protest after discovering COVID-19 pandemic is a fraud.',
#        'Neem tea is the â€˜solutionâ€™ for COVID-19',
#        'Covid 19 : â€˜Achha Chalta Huâ€™ Boy breathed his hast after singing a Hindi song.',
#        'A map of Sri Lanka was shared with certain cities highlighted as the places visited by close contacts of Kandakadu COVID19 cluster',
#        'COVID-19 hospital flooded in Bihar',
#        'A video of a man attacking a cashier at a McDonaldâ€™s restaurant has been viewed thousands of times in multiple posts on Facebook alongside a claim it happened in Singapore.',
#        'A text that ensures that the guava tree leaf can â€œprevent or reverseâ€\x9d the effects of COVID-19.',
#        'A student from Pondicherry University has found a home remedy for COVID-19 that has been accepted by World Health Organization (WHO)',
#        'Doctors perfoms a c-section in COVID-19 pacient and give birth to a baby without cuttin the membrane that protects him as a way to prevent contamination',
#        'Masks produce hypoxia and hypercapnia.',
#        'Africa managed the pandemic by prescribing ivermectin.',
#        'A video shows monkeys attacking Gandhi Hospital in Hyderabad',
#        'Pistol shaped infrared themometers are dangerous and can burn neurons.',
#        'Eiffel tower reopens with hommage to COVID-19 deaths.',
#        'A text about how no one is to be blamed for the pandemic in Brazil written by Mario Sergio Cortella, a Brazilian writer and philosophy professor.',
#        'A video of an excerpt from an American television program in which the presenter criticizes the use of masks and, as part of that criticism, supposedly measures the oxygen levels inside the mask that a child is wearing.',
#        'The low number of deaths from COVID-19 in Japan is due to the â€œdifference in the level of â€˜social standardsâ€™ between Japan and other countriesâ€\x9d.',
#        'Bolivia approved the use of chlorine dioxide, amid the fight against covid-19.',
#        'A picture allegedly shot in Brazil which would show a row of black bags containing corpses, and a man who is easily moving one of them using just one arm.',
#        'Video shows the dead bodies of Covid-19 patients being dumped in the ocean in Mexico.',
#        'Gas sensors show that wearing a face mask leads to oxygen deficiency and carbon dioxide toxicity.',
#        'Video of a doctor hitting a COVID-19 patient. The doctorâ€™s blows are believed to have killed him',
#        'Story claims to show a little girl who died of COVID-19.',
#        'Drinking a mixture of turmeric powder, cloves, lemon and ginger called kashayam cures COVID-19',
#        'A test on video with a gas detector shows that face masks result in dangerous oxygen levels for the wearer.',
#        'A painting depicting children in face masks was created as a mural for the Denver airport in 1994, proving the COVID-19 pandemic was planned.',
#        'A clip from Mexico depicts the dumping of coronavirus patients corpses into the sea.',
#        'The woman shown in this photo holding a baby is COVID-19 positive.',
#        'A video that compares the progress of hospitals in La Matanza (Buenos Aires, Argentina).',
#        'Video shows a doctor from Breach Candy Hospital of Mumbai claiming that If you can hold your breath for a longer period without discomfort, you donâ€™t have Coronavirus.',
#        'A video in which the man introduces and dubs another video from an interview with Stefano Montanari in the Byoblu video blog. Montanari calls himself a â€œnanopathologistâ€\x9d and claims that masks cause us to inhale the carbon dioxide that we expelled by breathing. This supposedly produces hypercapnia (excess carbon dioxide).',
#        'A picture with a quote attributed to the Nobel Prize DÃ©nis Mukwege, where he says that he was obliged to classify all the recent demises as Covid-19 related deaths.',
#        'Information circulating across social media platforms claims that Nigeriaâ€™s Federal Government has approved to disburse 30,000 to citizens as Covid-19 lockdown funds.',
#        'The Corona Cooking Survey shows that both men and women bake more often, that men enjoyed cooking more before quarantine, but that the difference with women has narrowed in recent weeks. Women in particular continue to find dining together more important.',
#        'Infrared thermometers damage neurons.',
#        'The title of an article suggests the low-cost steroid dexamethasone will heal anybody with COVID-19.',
#        'Congolese Nobel Prize Denis Mukwege said he doubted COVID-19 was real',
#        'Senegalese doctor says chloroquine is the secret for a very low number of deaths by COVID-19 in Senegal.',
#        'A text by C. S. Lewis, from 1942, talks about a â€œpandemic of fearâ€\x9d. It says the devil took many souls to hell because they became too attached to their earthly lives, through fear.',
#        '5G antennas are being installed in PopayÃ¡n, Columbia.',
#        'â€œOSHA says masks donâ€™t workâ€\x9d to reduce COVID-19 transmission â€œand violate OSHA oxygen levels.â€\x9d',
#        'Video of a man dressed in white who recommends taking ivermectin, aspirin, and ibuprofen to treat COVID-19. Thatâ€™s the formula they used in Australia.',
#        'The Argentinian company La Campagnola closed due to quarantine measures.',
#        'This video of the Eiffel Tower shows a tribute to victims of Covid-19.',
#        'Bill & Melinda Gates Foundation building says â€œCenter for Global Human Population Reductionâ€\x9d on its front.',
#        'Facebook is using your pictures and posts in lawsuits against the company amid the COVID-19 pandemic.',
#        'â€œIf we stopped testing right now, weâ€™d have very few cases, if any.â€\x9d',
#        'â€œGeorge Floydâ€™s â€˜murderâ€™ filmed before COVID-19.â€\x9d',
#        'â€œFREE HORSES!!!! 52 thoroughbred horses need homes. Will go to Sugarcreek this Sat. for slaughter. Gentleman died due to COVID-19 and his son wants nothing to do with them.â€\x9d',
#        'A message claims that ingredients in coffee can cure COVID-19 and that the deceased whistleblower Li Wenliang found its cure',
#        'Images of a man dressed in a hospital gown who seems to run away jumping a wall of the building. According to the caption, this man reported that he had gone to the health center to heal a wound in his hand when they assured him that he should be admitted for COVID-19 and that when â€œthey were going to connect a ventilator, he decided to jump from the second floor and escapeâ€\x9d.',
#        'The video of doctors singing â€œResistirÃ©â€\x9d with guitar and face masks happened in Mexico.',
#        'Video shows man holding bodies in sacks with only one hand.',
#        'Zee News claims that lockdown will apply again from 15 June in India.',
#        'An audio that claims that a group of criminals disguised as doctors robbed 3 houses in Flores, Argentina.',
#        'Video shows celebrations in Tunisian hospitals because Tunisia is free from COVID19.',
#        'Germanyâ€™s government has sent China a â‚¬149 billion charge for damage caused by the pandemic.',
#        'Kerala (India) temple offers special Puja for curing COVID-19 and a rate card for the specific COVID-19 prayer (rituals) has been created by the temple.',
#        'Asian giant hornet have been killing people in several countries, in an attack worse than the COVID-19 pandemic.',
#        'Onion cures and prevents COVID19.',
#        'A message that states that â€œAn asymptomatic person is a HEALTHY person. He is someone who has a virus but his body developed antibodies. This is calledâ€\x9d attenuated virus â€œ, which means that he dominated the virus thanks to his healthy lifestyle habits. This person does not spread the virus, but communicates antibodies to the rest of the people and generates herd immunity.',
#        'Those fake mortuary bags prove COVID-19 is a hoax',
#        'A school in Delhi is selling Facemasks for 400 rupees to students',
#        'Face masks cause hypoxia; wearing it causes one to inhale too much carbon dioxide, which can make you sick.',
#        'COVID-19 is not new and an old textbook gives out its treatment.',
#        'A chain on plasma donation of recovered COVID-19: any person who has recovered can donate plasma to 9 people.',
#        'â€œCOV 19â€\x9d was found inscribed on a circuit board for a 5G mast.',
#        'Horrific pictures of large numbers of victims of Covid-19. â€œToday, Americaâ€™s Game has been exposed, a young man with an enveloped doll to look like a victim of the virus, but in reality they are all just dolls that have been wrapped and spread on the streets of Americaâ€\x9d, says the caption.',
#        'A video claims to show a â€œdeadly insect attackâ€\x9d in China, India and Iran, in which the insect can supposedly kill a person with just one bite.',
#        'Smelling vinegar is not a definitive test to detect symptoms of COVID-19.',
#        'Italy did not follow WHO protocol and did an autopsy on a corpse that died from COVID-19 and realised that coronavirus is actually not a virus but a bacterium which gets amplified with 5G electromagnetic radiation that also produces inflammation and hypoxia, and multiple other claims.',
#        'Uganda Red Cross Society in partnership with the United States Agency for International Development (USAID).',
#        'There were no COVID-19 deaths in Fortaleza, Brazil, on May 29.',
#        'The use of masks for COVID-19 causes hypoxia.',
#        'A picture claiming that Lidl is offering free shopping vouchers for €180 in Italy.',
#        'Lionel Messi said “there was a planetary coup d’etat” with the coronavirus pandemic.',
#        'Video shows migrants looting food packets at Hyderabad Railway station, in India.',
#        'Man seen in viral images was a COVID-19 patient who fell in love with his lady doctor. The two got engaged in the same hospital in Egypt.',
#        'Man found alive in burial bag in the Brazilian state of Bahia.',
#        'Italian doctors discovered that COVID-19 causes thrombosis instead of pneumonia by doing autopsies on the dead, which is prohibited by the WHO.',
#        'One person has been stabbed during a protest against the government in the neighbourhood of Moratalaz in Madrid.',
#        'Sanitiser bottles inside a parked car triggered fire due to heat wave in Bhopal.',
#        'A photo shows the installation of a hidden 5G antenna.',
#        'Bill Gates said ‘thousands of people will die with the COVID-19 vaccine’',
#        'An image of a surgical mask with various messages. The main one is that using it makes you breathe your own carbon dioxide.',
#        "False: South Sudan's Chief Justice, Family Refused Testing For",
#        'False: Muslims Ignore COVID-19 Curfew, Convene At Mosque In Sri Lanka',
#        '1869 Poem Reprinted During Spanish Flu Pandemic Resurfaces In 2020?',
#        'Video Of Orangutan Washing Hands Falsely Linked To COVID-19 Pandemic',
#        'No, The Queen Did Not Test Positive For COVID-19',
#        "False: Rail Tanker Stamped With 'COVID-19'",
#        'Does This Infographic Show The Correct Timeline Of the COVID-19...',
#        "Old Video Edited To Show Jack Ma Praising China's Response To COVID-19",
#        "No, A US Soldier Didn't Wipe His Saliva On A Subway Train In Wuhan",
#        'Breathing In Hot Air From Sauna, Hair Dryer Does Not Treat COVID-19',
#        'Consuming Silver Particles Does Not Prevent Or Treat COVID-19',
#        'Italians Quarantined In Brothel? Satire News Goes Viral',
#        'US Radio Host Rush Limbaugh Falsely Likens COVID-19 To Common Cold',
#        'Coronavirus: Philippines Refutes Fake Advisory On Visiting Malls',
#        'No, Tom Hanks Not Gifted A Volleyball In Coronavirus Quarantine',
#        'False: Cambodian PM Hospitalised After Contracting Coronavirus',
#        'Has WHO Advised Against Isolation & Social Distancing? Not Really!',
#        'Video of COVID-19 Mock Drill in Colombia Shared as Real Incident',
#        'No Link to Ramzan, Viral Clip Shows Argument Between Cops & Abuser',
#        'Viral Clip of Mayhem Outside Delhi Liquor Store – It is From Feb',
#        'Muslims Attacked Cops in Maharashtra’s Malegaon? It’s Fake News',
#        'WebQoof Recap: Fake Claims Around Bandra Migrant Crisis & More',
#        'Still From TV Show Used to Claim Over 200 Medics Died in Italy',
#        'Bodies of COVID-19 Patients Dumped in Sea? No, Video is From 2014',
#        'Viral Video of Amitabh Bachchan Thanking Nanavati Medics is Old',
#        'Mohan Bhagwat Never Said He Lost Faith in Religion Amid COVID-19',
#        'Overcrowded Train Carries Migrants From Mumbai to WB? Video is Old',
#        'Gujarat Woman Killed Daughters & Self Due to Hunger? Fake Alert!',
#        'Bihar Confirms Chicken as COVID Source? Fake Clipping Goes Viral',
#        'Video of Pak’s JUI-F Leader on Lockdown Being Shared as From India',
#        'Unrelated Clip Shared to Claim ‘Migrants Robbing People for Money’',
#        'Viral Post on ‘Dr Devi Shetty’s 22 Steps Against COVID-19’ is Fake',
#        'Old Picture Used to Claim Pregnant Woman Tested Positive for COVID',
#        'Video of Man Violating Lockdown  in Dehradun Given Communal Spin',
#        'Old Video From Pakistan Shared to Claim Tablighi Man Roaming Naked',
#        'WebQoof Recap: Of Communally Charged Claims and Alarmist Messages',
#        'Old Video From Philippines Shared  With ‘Corona Jihad’ Spin',
#        'COVID-19: No, MCI Hasn’t Asked Hospitals To Recruit MBBS Interns',
#        'Old Video Used to Claim ‘US Accepts Quran’ to Fight COVID-19',
#        'WebQoof Recap: From COVID-19 Infodemic to BJP MP on Delhi Violence',
#        'Cop Extorting Money from Migrant Caught on Cam? No, Video is Old',
#        'Mustard Oil  Helps Fight COVID? Ramdev’s Claim Lacks Medical Proof',
#        'No, This Man Wasn’t Seen Spitting on Fruits in Delhi’s Bawana',
#        'COVID-19 Misinformation Is Keeping Fact-Checkers on Their Toes',
#        'Unrelated Images Shared as Current Situation of Bihar’s COVID Ward',
#        'WebQoof Recap: Trolls Target Safoora; Experts on AC During COVID',
#        '2018 Image From UP Shared as Namaz Offered in TN Amid Lockdown',
#        'Satyendar Jain Misquoted to Claim None From Markaz COVID Positive',
#        'Mock Drill Video Shared as COVID-19 Case in Bihar’s Hajipur Jail',
#        'Video of Man Spitting at Subway Rider Falsely Linked to COVID-19',
#        'Dead COVID-19 Patients in Italy? Pictures are Old & Unrelated',
#        'WebQoof Recap: From COVID-19 Being Airborne to Misleading Cures',
#        'Old Video Shared as COVID-19 Suspects Landing in Ethiopian Airport',
#        'OpIndia Runs Fake News On Muslims Refusing to Be Tested in K’taka',
#        'Old, Unrelated Clip  Viral as Migrants Stranded at Delhi-UP Border',
#        'Fungus on Leather Goods in Malaysian Mall Claimed to Be From India',
#        'Old Video From Pak Shared as Women Flouting Norms Amid Lockdown',
#        'Old Video Used for False Claim of Muslims Flouting Lockdown in Guj',
#        'Nobel Laureate Tasuku Honjo Didn’t Say COVID-19 Was Made in China',
#        'Tricolour on Matterhorn to Thank India For HCQ Supply? Fake Claim!',
#        'People Violating Lockdown in Gujarat? No, Image is from Malaysia',
#        'Old Video Shared as Man Killing Self After Losing Kin to COVID-19',
#        'Bodies of COVID-19 Victims Being Dumped in Italy? No, a Film Scene',
#        '4G Internet Being Restored in Jammu? No, the Order Is Fake',
#        'Film Scene Shared as Mass Graves in Italy Due to COVID-19 Deaths',
#        'Muslims Rejoicing the Quran Ban Being Lifted in China? Fake Alert!',
#        'A photo shows a large crowd in Berlin protesting the “covid hoax.”',
#        '“This virus has a cure. It is called hydroxychloroquine, zinc, and Zithromax. I know you people want to talk about a mask. Hello? You don’t need (a) mask. There is a cure.”',
#        '“You must apply to get your second stimulus check! I’ve already filed for mine and will be receiving $2,000 a month for the rest of the year.”',
#        '“FREE HORSES!!!! 52 thoroughbred horses need homes. Will go to Sugarcreek this Sat. for slaughter. Gentleman died due to COVID-19 and his son wants nothing to do with them.”',
#        '“N95 masks block few, if any” COVID-19 particles due to their size.',
#        'A photo shows three men on crosses who “feel like they’re being crucified by being required to stay at home.”',
#        '“A lot of people can get an additional $2,400” from the CARES Act “and they can do it every month!”',
#        'Bill Gates worked to end livestock production, and is pushing lab grown meat.',
#        'Says only certain face masks are effective and others, such as cloth masks, are not.',
#        'Black cats in Vietnam are being killed and consumed as a COVID-19 cure.',
#        '“New autopsy reports suggest Jeffrey Epstein most likely died from COVID-19 complications.”',
#        "Says Bill O'Reilly wrote a post claiming that the coronavirus was created as a bioweapon by the Chinese government.",
#        'Hochul writes history with ventilator claims',
#        'Says this poem about people staying home was written by Kathleen O’Mara in 1869.',
#        '“This lady here applied sanitizer to her hands/forearms & went to the kitchen to cook. The moment she turned on the gas stove, her hands caught fire due to the alcohol contained in the sanitizer.”',
#        '“if your child gets this virus their going to hospital alone in a van with people they don’t know...to be with people they don’t know… you will be at home without them in their time of need.”',
#        'Says you can monitor yourself for COVID-19 with a breath test.',
#        'Video of Migrant workers escaping from a train carrying them to Assam in Nagaon, India by stopping the train.',
#        'Mumbai policewoman felt dizzy and fell down as she tested positive for COVID-19.',
#        'Mumbai Police congratulated a couple for marrying inside their house amidst the coronavirus lockdown.',
#        'Consuming 3 times a day a mixture of the juice of 10 lemons, honey, ginger, onion and 10 garlic cloves is the recipe that “prevents the coronavirus” and helps “recover from the virus”.',
#        'A nurse from the city of Bucaramanga, Colombia, was attacked with stones by people who said she was going to infect them with COVID-19.',
#        'Prolonged use of face masks causes hypoxia.',
#        'Video shows migrants vandalizing public property in Surat during the COVID-19 lockdown.',
#        'Facebook posts shared hundreds of times in South Africa claim that criminals posing as government officials are going around to people’s homes and distributing face masks that are laced with chemicals to knock them out and rob them.',
#        'A video is circulating on social networks showing an alleged death in Chiquimula, Guatemala.',
#        'Lactancy is not recommended because of risks to COVID-19 transmission from mother to child.',
#        'Sloth bear seen in a house garden in Sri Lanka during the COVID-19 lockdown.',
#        'The prolonged use of masks can cause hypoxia.',
#        'The COVID-19 pandemic “was set up in a meeting” in 2019 sponsored by the Bill & Melinda Gates Foundation.',
#        'Facebook allegedly removed a video criticizing Dutch social distancing rules.',
#        'A blog article stating that COVID-19 has been misdiagnosed, as the deaths would be caused by problems linked with thrombosis in the first place. According to the article, the two scientists who discovered this have received an “international prize”',
#        'RSS chief Mohan Bhagwat said he has lost faith in religion due to coronavirus pandemic.',
#        'A family friend of prominent playwright Ratnakar Matkari said he was infected with coronavirus through outside mild packages.',
#        'RSS Chief Mohan Bhagwant’s said that COVID-19 shook his faith in religion.',
#        'A post says that a bottle of alcohol gel left in a car caused a fire that damaged one of its doors.',
#        'A WhatsApp message claims that Italy announced the cure for COVID-19.',
#        'EUMM (European Union Monitoring Mission) is collecting biologial materials for dangerous experiments in the Lugar Lab alongside South Ossetian border. This is provied by the photos of medical car accompanying the mission patrols.',
#        'Uhuru Kenyatta Foundation is giving out Ksh10,000 to each Kenyan as lockdown relief funds.',
#        'Amid COVID-19 pandemic, Bosnian Croats were targeted and penalized at the state border upon entry into Bosnia and Herzegovina',
#        'Substances present in the boldo and in the quina plant treat COVID-19.',
#        'South Sudan’s president and senior ministers have appeared in public in recent weeks wearing so-called “virus removal cards”, clip-on tags marketed as prevention against infectious diseases. AFP Fact Check found the items for sale online in various countries, including Lebanon, Malaysia and the Philippines.',
#        'The Algerian President, Abdel Majid Taboun, awarded the National Order of Merit to the family of the martyr doctor Wafaa Boudissa, and her name was given to a hospital in the country.',
#        'Social media posts claim that actors were caught in the act staging fake COVID-19 cases.',
#        'Viral message showing roadmap to ease restrictions during COVID-19 is from India.',
#        'A video shows an evangelical pastor offering an invisible spiritual mask against COVID-19, H1N1 and HIV.',
#        'Switzerland banned vaccination and someone named “Father Escobar” said that through vaccination, “Satan inserts a code into a human body.”',
#        'Video shows migrant workers raising “long live Pakistan” slogans when returning their home state during lockdown.',
#        'Tanzania has reported 16,467 COVID-19 cases, 1,293 deaths, and 118 recoveries as of May 18.',
#        'A post that shows the level of radioactivity of 5G antennas in Argentina.',
#        'The water in Botafogo’s beach in Rio de Janeiro, Brazil, is clear and clean because of quarantine.',
#        'The Tunisian President, Qais Said, has ordered the dispatch of a medical delegation to Algeria to help it fight Coved-19.',
#        '5G networks worsen the COVID-19 spread.',
#        'During the protest in the Salamanca district in Madrid, people sang ‘Bella ciao’.',
#        '90 percent of violence against women calls to 911 in Mexico are not true.',
#        'Archbishop of Colombo, Sri Lanka, Cardinal Malcom Ranjith filed a FR petition challenging the cremation of Catholics, who succumbed due to COVID-19.',
#        'WHO officially recognized artemisia as a treatment for COVID-19.',
#        'Migrants in Mumbai robbed and killed a man for money due to the lockdown.',
#        'Video shows a toxic insect attack in India during the COVID-19 pandemic.',
#        'A video of street play showing Muslims responsible for spreading coronavirus.',
#        'Alcohol gel bottles can explode in a hot car.',
#        'Facebook posts shared thousands of times claim that people in Lesotho are “immune” to COVID-19 because the country apparently created a remedy for the disease.',
#        'Parrots eating from rice bag due to lockdown.',
#        'Mask made of copper oxide can be more effective to avoid COVID-19.',
#        'Pranab Mukherjee, a man of all seasons',
#        'Mozilla Lays Off Nearly 250 Employees, Ceases Taipei Operations Due to \nPandemic-Hit Revenues',
#        'COVID-19: Google commits $6.5 Mn to fight misinformation',
#        'Google hosts webinar on dealing with misinformation amid COVID-19 pandemic',
#        'Google to reopen offices from July 6, will give employees working from home \nRs 75K allowance',
#        'How to find authorised Covid-19 testing centres using Google Maps and \nGoogle Search',
#        'Google and Facebook support new Covid-19 solidarity response fund',
#        "COVID-19 Isn't Slowing AWS And Google's Data Center ...",
#        'Google expands work from home recommendation to all North American \nemployees, establishes ‘COVID-19 fund’',
#        'Google purged 2.7 billion bad ads in 2019, COVID-19 fake ads next target',
#        'Google, Apple join hands to develop coronavirus contact tracing system',
#        'Google sees 18mn COVID-19-linked malware, phishing emails daily',
#        'Google makes education push in India',
#        'Google Hyderabad begins screening employees',
#        'AP COVID-19 Tally Crosses 2.5 Lakh Mark With 9,597 New Cases',
#        "No COVID Patient Must Suffer Due To Financial Reasons': Odisha CM Naveen Patnaik",
#        'Covid-19: Puducherry CM announces total lockdown on every Tuesday',
#        'Record 7,883 Covid cases in K’taka, 2,802 in Bengaluru alone',
#        'Mohammad Hafeez breaches biosecurity protocol, to stay in isolation until he tests negative for Covid-19',
#        'Bhubaneswar records 187 new COVID-19 cases in last 24 hours; tally at 4,358',
#        'Covid-19 Risks Overwhelming Beirut as Blast Knocks Out Hospitals',
#        'COVID-19 spreads wings in capital and Suburbs',
#        'Valencia sold duo due to financial strain caused by COVID-19, says president',
#        'COVA Mobile App, helping citizens and government agencies during COVID-19 pandemic:: Vini Mahajan',
#        "COVID positive Andhra headmaster died due to hospital's negligence: Chandrababu Naidu",
#        'Lucknow records highest spike of 831 Covid cases in a day',
#        'Punjabis’ koi gal nai attitude working against them during Covid-19: Capt',
#        'Covid death toll drops by 5,000 after figures review',
#        'A couple committed suicide along with their daughter amid the COVID-19 lockdown in Gujarat.',
#        'Two Muslims boys were brutally beaten and forcefully fed alcohol by Hindu boys in India.',
#        'Every Indian citizen to get Rs.5000 as COVID-19 relief by clicking on this link given in the viral Whatsapp message.',
#        'Philippines Senators Grace Poe and Risa Hontiveros have been silent over the coronavirus crisis, but were very vocal about the closure of ABS-CBN.',
#        'A man collapses in 5 minutes after showing COVID-19 symptoms in India.',
#        'A video that shows 4 allegedly empty hospitals in SÃ£o Paulo.',
#        'Video shows fishes washed up to the Indian shores during the lockdown.',
#        'â€œBill Gates already has his vaccine ready for you (against covic-19, ed.), And hereâ€™s the patent.â€\x9d',
#        'A video with a text message, allegedly endorsed by Police forces, saying that the Police will rebel against the Italian government â€œif the situation goes on like thisâ€\x9d.',
#        'An image of a man carrying his old mother on his back shows migrants travelling to their homes in India, amidst lockdown.',
#        'Green or black tea with lemon and two spoons of fennel flower cures COVID-19.',
#        'There is a case of COVID-19 on the Rohero campus of the University of Burundi.',
#        'Missing COVID-19 blood samples discovered in the streets of BihaÄ‡, in northwestern Bosnia and Herzegovina',
#        'Prolonged use of protective masks causes hypoxia.',
#        'Due to the increase in excise tax by 70% for locally manufactured alcohol, the price of bottle of Arrack would be increased to over 3000 LKR, to discourage alcohol consumption once the liquor shops finally open after a long break due to COVID-19 precautionary measures.',
#        'Video shows a policeman taking bribe from migrating workers in Surat.',
#        'Video shows that those who go to shopping malls are greeted with the â€œCoffin Danceâ€\x9d music.',
#        'Photo shows the queue in front of a shopping center in Turkey.',
#        'A video with the caption â€œhe doesnâ€™t want to wait for another 14 days.â€\x9d shows a guy falling from a building after grabbing high tension wire.',
#        'Two men robbed gold and money, asking the victim to put on a mask.',
#        'Photo: Thousands of birds fall dead amid the COVID-19 pandemic.',
#        'Wearing a traditional turban as it is done in the Songhoy (or Songhai) culture is both an ancestral practice and a preventive measure against COVID-19.',
#        'A video of a Brazilian man claiming that azithromycin and ivermectin cure people with COVID-19.',
#        'People violate social distancing protocol in a temple festival in Alappuzha, India.',
#        'Image of a doctor smoking while treating COVID patients in Gujarat, India.',
#        'An image claims it shows the Grand Canal of the Italian city of Venice full of what the caption calls â€˜pink swansâ€™.',
#        'Statistics of deaths per million inhabitants show that COVID-19 pandemic in Brazil is not serious.',
#        'â€œAutopsies prove that COVID-19 isâ€\x9d a blood clot, not pneumonia, â€œand ought to be fought with antibioticsâ€\x9d and the whole world has been wrong in treating the â€œso-calledâ€\x9d pandemic.',
#        'Hand sanitizer can burst into flames if you leave it in your car.',
#        'Dr. Anthony Fauci is â€œpushingâ€\x9d remdesivir as a potential COVID-19 treatment drug, because he â€œinventedâ€\x9d it with Bill Gates and they stand to profit from it.',
#        'Captions on a reuploaded video about the U.S. approving Remdesivir for emergency use say the drug will â€œend COVID-19.â€\x9d',
#        'More than one hundred people in Quarantine center in Chin State, Myanmar, died.',
#        'Migrants are defying lockdown and have taken to Ahmedabadâ€™s streets in India.',
#        'Multiple posts shared hundreds of times on Facebook purport to show a list of notable viral outbreaks between 1950 and 2019 which â€œoriginated in Chinaâ€\x9d.',
#        'A TikTok video showing a woman buying liquor after the ease of the coronavirus lockdown in Mumbai claims that she is Bollywood actress Deepika Padukone.',
#        'TV Globo used images of a collective funeral for the victims of a shipwreck in Lampedusa, in 2013, to illustrate a story about deaths by COVID-19 in Italy.',
#        'A video shows a Maasai tribe member in Kenya whipping people who violate the countryâ€™s curfew during the coronavirus pandemic.',
#        'Burundi had 274 cases of COVID-19 and only one death on April 30.',
#        'Congolese researcher JÃ©rÃ´me Munyangi is at the base of the discovery of COVID-Organics.',
#        'Supermarket chain, Melcom is giving out GHâ‚µ 2,000 gift cards to every Ghanaian in response to COVID-19.',
#        'â€œDr. Fauci sat on Microsoftâ€™s board of directors.â€\x9d',
#        'The government and Bill Gates have overshadowed the social profiles of De Donno, the doctor who experiments with plasma treatment in the Mantua hospital. Matteo Salvini: â€œWhoever touches Bill Gatesâ€™ business disappearsâ€\x9d.',
#        'A video has been viewed more than 100,000 times in multiple Facebook posts that claim to show a 5G mast burning in the Italian city of La Spezia.',
#        'Video of women fleeing from a quarantine center during the current lockdown in Shivaji nagar, Bangalore.',
#        'A new danger is coming: Asian hornets has killed 28 people in China.',
#        'Ozone serves as a disinfectant against COVID-19.',
#        'Video: Americans singing Indian National Anthem thanking India for giving hydroxychloroquine.',
#        'People held a â€˜street partyâ€™ in Dublin on 1 May.',
#        'Women of Shaheen Bagh, in Delhi, India caught red-handed carrying out a prostitution operation during the lockdown',
#        'Deer spotted in Tokyo during lockdown.',
#        'Pope Francis allows the use of artificial intelligence to implant microchips.',
#        'Tailors have been forbidden to sell non homologated masks in France.',
#        'Flower named Brahmkamal bloomed after decades due to the decrease of pollution caused by the lockdown.',
#        'A picture allegedly showing 500 people gathering in Livorno (Italy) to protest against the lockown.',
#        'WHO said artemisia plant cures COVID-19.',
#        'For several days, an article by a Spanish organization in which COVID-19 is an â€œexosome influenced by electromagnetic pollutionâ€\x9d has been circulating on social media and WhatsApp.',
#        'The Washington Post claims the new coronavirus was created on a Wuhan lab.',
#        '96,3% of people deceased in Italy from COVID-19 actually died from other illnesses, according to this deputy.',
#        'CRAS (a social care center) is distributing 492 thousand market baskets to people in need. People need to fill out a form to find out if they are eligible.',
#        'A fake picture allegedly shows how coronavirus can pass through protective masksâ€™ fabric.',
#        'Video of Muslims violating lockdown conditions in Old city (Hyderabad).',
#        'A photo shows Proud Boys member Rob Cantrall at a recent Michigan protest.',
#        'In a video, blogger Ken Jebsen claims Bill Gates took control over the health system to force his vaccines upon everyone. He funds 80 percent of the WHO. In Germany people are arrested because they carry the constitution (Grundgesetz). Germany secretly wants to impose compulsory vaccines in a new law, and COVID-19 is just a harmless flu',
#        'A family built a homemade mechanical respirator that cures COVID-19 with inhalations.',
#        'Someone living in Cercerda (Galicia, Spain) died under â€œstrange circumstancesâ€\x9d.',
#        'A publication of the website MediterrÃ¡neo Digital that states in its headline that â€œthe Government allows the celebration of Gay Pride in Madrid despite the coronavirusâ€\x9d',
#        'Government of India will provide a relief package of Rs 50,000 to ration card-holders under its scheme â€˜Rashtriya Sikhshit Berojgar Yojnaâ€™.',
#        'Cameroonian bishop Mgr Samuel Kleda revealed the recipe of a drink that can cure COVID-19.',
#        'A video shows Chinese soldiers burying COVID-19 infected bodies without using protection equipment.',
#        'Image of Kaziranga national park in Assam, India during lockdown.',
#        'A publication on the purchase of respirators by the Province of Buenos Aires. According to the publication, the Buenos Aires government would buy respirators from China for 10 million dollars,',
#        'A photo shared hundreds of times on Facebook claims to show the American cable news channel CNN describing cases of COVID-19 in Nigeria as â€œfalseâ€\x9d, accusing the government of making them up to embezzle public funds.',
#        'New WHO guidelines recommend encouraging children under four to masturbate.',
#        'Golf courses are reopening in Ireland on 2nd May.',
#        'The Bill and Melinda Gates Foundation headquarters is called the â€œCentre for Global Human Population Reductionâ€\x9d.',
#        'First load of Moroccan masks and respirators arrived in New York City.',
#        'Social media users have shared a photo that claims to show a â€œCenter for Global Human Population Reductionâ€\x9d affiliated with the Bill & Melinda Gates Foundation.',
#        'Prolonged use of mask can cause hypoxia.',
#        'Poem written in 1869 by Kathleen Oâ€™Meara predicted the pandemic of COVID-19.',
#        'Brasilian doctor discovered a cure for COVID-19.',
#        'Alfalfa is the only cure for COVID-19.',
#        'Prolonged use of the mask causes hypoxia.',
#        'Photo shows a broken refrigerator with 1500 viruses in Wuhan.',
#        'President of Russia, Vladimir Putin, has ordered COVID-Organics and asked Africans not to follow the World Health Organization (WHO).',
#        'Japanese family converts to Islam after they are cured from COVID-19.',
#        'The photo shows bedding and food aid packages distributed in Rwanda during the coronavirus pandemic',
#        'Indian Spritual Guru Mata Amrithanandamayi Charitable trust gifts India its first â€œAir Ambulanceâ€\x9d.',
#        'Bollywood Superstar Aamir Khan donated Rs.15000 each to poor slum dwellers in one kg wheat flour packets.',
#        'Old Dalit woman beaten up by Christian missionaries in Kerala.',
#        'Bill Gates is creating vaccines to make the earthâ€™s population infertile. He discussed a plan to reduce the worldâ€™s population through vaccines during his 2010 TED talk.',
#        'â€œGovernor Andy Beshear has authorized Kentucky teachers to make in-home visits. With parental approval, teachers will inspect the bedroom of each student currently enrolled in K-8.â€\x9d',
#        'Joy Arakkalâ€™, the owner of â€˜Joyalukkasâ€™ jewellery company, has died due to COVID-19 in the Middle East.',
#        'Thai police arrested a cat for disobeying the curfew order.',
#        'A family (husband, wife, child) committed suicide because they could not bear hunger. They were migrants travelling to their hometown during the lockdown, from a city named Surat in India.',
#        'Carrefour is selling face masks in its physical stores above the maximum price set by the Government of Spain.',
#        'A video showing a Muslim woman misbehaving with doctors in India.',
#        'A video published by a Columbian page on Facebook, which has been shared more than 34,000 times on that social network, claims that a German newspaper â€œhas sued China.â€\x9d',
#        'Picture shows clothes of those who have died of coronavirus in China. Beijing is now shipping these clothes to Africa.',
#        'The coffins with the bodies of the dead of Bergamo were not a hoax.',
#        'Huge crowd on the streets of Delhi during Ramzan while there was no crowd during the festival of Navratri.',
#        'Video shows a baby was delivered with its amniotic sac because the mother has COVID-19.',
#        'Nobel Prize Tasuku Honjo says the coronavirus was created by man in Wuhan.',
#        'A video of a car on fire. In the caption, it says that alcohol-based hand sanitizer caused the fire.',
#        'A video of a speech by Tedros Adhanom Ghebreyesus. On a voiceover, a man says that he is warning Brazil that imported masks from China and India are contaminated with the SARS-Cov-2',
#        'The owner of the Indian jewellry group Joyalukkas died due to COVID-19.',
#        'Romanian president Klaus Iohannis says a school reopened in France for an experiment and it failed. Many pupils were positive.',
#        'The COVID-19 pandemic was used as a cover-up of the Starlink project by Elon Musk, which launched dozens of satellites.',
#        'Seven children in Senegal are dead due to coronavirus vaccine testing.',
#        'Image shows the last moments of a mother and child suffering from COVID-19.',
#        'Japanese Nobel Tasuku Honjo says coronavirus was created in the Wuhan laboratory',
#        'Implantation of nanochips has started in Ukraine.',
#        'Honey and olive oil cure COVID19 according to a Holy dream.',
#        'The 3 year old son of the Puerto Rican artist Luis Fonsi, Rocco RodrÃ\xadguez LÃ³pez, has died of COVID-19.',
#        'Image of swollen feet of starving children who walked miles for food in Uttar Pradesh amid COVID-19 Lockdown.',
#        'Dr. Megha Vyas from Pune died of COVID-19.',
#        'This image shows a mother suffering from COVID-19 holding her baby.',
#        'A video shows a woman demonstrating how mixing rum and bleach can make rubbing alcohol.',
#        'Thieves give masks with â€˜chemicalsâ€™ to victims to put them to sleep.',
#        'In a speech, Italian politician Vittorio Sgarbi say there are not 25.000 deaths in Italy â€“ 96 percent of the deceased died of other causes.',
#        'Bathing in bleach cures COVID-19.',
#        'Typing *#21# on your cell phone lets you know if youâ€™re being spied on because of COVID-19 geolocation measures in Quebec.',
#        'COVID-19 can be cured with an infusion of garlic, lemon and jambu (an Amazonian herb, used as a spice in Northern Brazil).',
#        'This photo shows a pregnant woman suffering from coronavirus',
#        'Image of a critically ill COVID-19 infected woman hugging her child for the last time before her death',
#        'A man in Wales was caught on video touching his groin and wiping his hands on a public lift.',
#        'Photographs of killer whales allegedly taken in El MÃ©dano, Tenerife during confinement by the coronavirus.',
#        'A video claiming that the $ 100 bills are being printed without a number in Argentina.',
#        'This video shows fishes overflowing out of the water in Goa, India because the fishery business has been halted due to the lockdown.',
#        'A woman infected with COVID-19 has been spitting and roaming inside a departmental store at Reliance Mall in Rani Bagh, Delhi.',
#        'Tunisian researcher speaking in this video found a cure against COVID-19.',
#        'A photograph of a woman hugging her young child before she died of COVID-19 in Italy.',
#        'The video of a father hugging his son in the middle of a seizure is shared with a text claiming itâ€™s related to COVID-19.',
#        'Lemon, mango, avocado, garlic, tangerine, pineapple and orange are good against COVID-19.',
#        'Famous French blue cheese, roquefort, is a â€œmedecine against COVID-19â€\x9d.',
#        'According to the documents leaked out from Bill Gates foundation, Chinese scientist, Mrs. Shih Zhengli is responsible for releasing the COVID-19 by placing a piece of polluted day ice near the Wuhan seafood market.',
#        'Claim that Indian actor Jaaved Jaaferi tweeted that it is not necessary that the Muslim fruit vendors applying spit on fruits should be COVID-19 positive',
#        'The incident of lynching of two Indian monks in Palghar amid lockdown was communal.',
#        'Lemon, aspirins and honey is the recipe against COVID-19.',
#        'Matterhorn mountain in Swiss Alps lit up with the Indian Tricolour after PM Narendra Modi supplied Hydroxychloroquine (HCQ) tablets.',
#        'Video shows a drone that delivers food amidst the quarantine in Japan.',
#        'Wine will protect you from COVID-19.',
#        'This picture shows a mass grave that has been built in Milan to bury people that have died from COVID-19.',
#        'Brigitte Macron asked Didier Raoult treat her daughter with chloroquine.',
#        'Image shows thousands of devotees gathered in religious fair in India amidst lockdown.',
#        'The image shows a daughter crying for her coronavirus infected mother who struggling for her life.',
#        'In Kerala, India, Consumerfed starts 24 hours free home delivery for liquor.',
#        'The photo shows that a man in Jordan died of COVID-19 was buried with his car',
#        'Bill Gates wants to implement microchips, to depopulate the planet and he is sued in India for killing people with vaccines.',
#        'A picture that is shared in Social Media explains how much wearing a face masks protects you against an infection using percentages.',
#        'You have to shave off your beard and moustache completely for mouth masks to be effective.',
#        'Video showing how Germans are converting to Islam in large numbers.',
#        'This viral image shows how effective face masks are.',
#        'Photo of an old Italian man crying after his health improved.',
#        'WhatsApp messages that claim that the Washington Post has confirmed that the origin of SARS-CoV-2 is due to a security breach in a laboratory in Wuhan.',
#        'Aung San Suu Kyi is number one among women leader in combating coronavirus.',
#        'Police takes harsh step against Temple Priest for violating lockdown norms.',
#        'Six thousand people deliberately convert to Christianity in Venezuela after a terrible struggle with the corunavirus.',
#        'A poster stating Pakistan has asked for hydroxychloroquine instead of Kashmir.',
#        'The FBI raided a Jewish synagogue in New York that hoards N95 masks.',
#        'Goodwill Industries International has fired all its employees because of the coronavirus pandemic.',
#        'Image of Gulbarga car festival held during lockdown this year.',
#        'Video of people thronging to a wine shop in Assam, India amid lockdown.',
#        'Migrant family walking from Surat due to the lockdown committed suicide due to starvation.',
#        'When a police officer enforced lockdown orders on people in a temple in India, he was beaten up there.',
#        'This photograph shows a large bunch of workers from Bulgaria who have been brought in to Ireland to pick fruit ignoring social distancing rules outside a Dublin supermarket',
#        'Photos of delivery of aid for upper strata (higher social classes) in Colombia.',
#        'Germany cancels strict quarantine and opens shops, museums, libraries, zoos.',
#        'A video in which a man cuts his neck on the street.',
#        'A Twitter user shared an image of a map of India.The caption reads, â€œThis is a map of India redesigned by an American CEO where he tried to explain that India is indirectly handling the COVID-19 situation of so many countries, owing to its large populationâ€\x9d.',
#        'A viral video show Hungarian policemen throwing old people in trucks to force them to go into quarantine.',
#        'A group of muslims pray together in roofs breaking the state of alarm in Spain.',
#        'Criminals in Ireland are dousing facemasks with chemicals and offering them to people, before robbing them.',
#        'The scientists who discovered the coronavirus genome were fired of the Argentinian Institute MalbrÃ¡n during the presidency of Mauricio Macri.',
#        'In the United States, there are â€œ360,000 (deaths) a year from swimming pools. But we donâ€™t shut the country down for that.â€\x9d',
#        'A man was beaten by the cops in Dehradun, India after he violated the lockdown norms and came out to spit on peopleâ€™s doors and handles.',
#        'Police catches coronavirus positive patient on the road.',
#        'The pandemic is a lie, COVID-19 can be cured with vitamin C and Bill Gates is behind it all.',
#        'The internet portal Oiga Noticias accused in a headline the Mayor of BogotÃ¡, Claudia LÃ³pez, of making fun of small and medium-sized companies.',
#        'Lion walking in a road and is going to Vaishno Devi shrine during lockdown.',
#        'Video showing how Italy started a conference reciting the Holy Quran.',
# ...
#        'Remedy recipe: (1) boil tea with bitter melon. (2) Lemon juice with salt or Chinese mesona',
#        'Image claims to show dozens of coffins of Italians who have died from COVID-19.',
#        'Homemade recipes for alcohol gel.',
#        'The canals in Venice have become cleaner after the shutdown, attracting schools of fish and dolphins.',
#        'A private lab was denied authorization to perform COVID-19 test.',
#        'Videos showing police raids or army raids against people who don’t respect confinement measures in Algeria or Morocco.',
#        'Video shows Italy turning to Islam after giving up by the Italian authorities',
#        'The exams to access university in Valencia region will be delayed to August 10, 11 and 12.',
#        'Javier Ortega Smith, from VOX, has said that he prefers to be infected by the new coronavirus than to “have homosexualism”.',
#        'This photo shows French nurses holding a sign to denounce police violence.',
#        'Man contracts COVID-19 by eating mutton.',
#        'Novel “The Eye of Darkness” predicts the coronavirus as a biological weapon from China',
#        'A hospital in Murcia in Spain has made a citizen appeal to make surgical masks.',
#        'Due to the fear of coronavirus, Muslims in China are offering Namaz in the open street.',
#        'This poem describes people applying social distancing during a plague outbreak from the 19th century.',
#        'A sensationalist headline, misleading readers: “Disturbing video: A proof that only today there are 349 dead in Italy, stay at home.”',
#        'France will pay rent, light and gas during quarantine for its citizens.',
#        'Video claiming:  panicked shoppers in Italy storm supermarket amid coronavirus pandemic.',
#        'Italy official Giulio Gallera: China lies to us. The date China provided is false. Italy has become Wuhan and the medical system has a breakdown.',
#        'A man is touching a push-cart with his tongue to spread the virus outside Lidl in Lithuania.',
#        'A mixture of vinegar and fabric softener is a better disinfectant than alcohol.',
#        'A “Spanish biological researcher” says “You give the footballer 1 million euros a month and a biological researcher 1,800 euros per month, and you are now looking for a coronavirus treatment. Go to Cristiano Ronaldo or Messi and they will get you a cure.” A quote published with a photo of this so-called “Spanish biological researcher.”',
#        'Emirati singer Ahlam’s Mask Is Crowned With Diamonds.',
#        'Water in Venice begins to become more crystalline, thanks to the ban in Italy by COVID-19.',
#        'Javier Ortega Smith, from VOX, has said he prefers to be infected by the new coronavirus than to “have homosexualism”.',
#        'Unclear official guidelines from authorities regarding outdoor activities in Denmark. Televised news report showing people outdoors in close proximity to each other casusing social media outrage',
#        'A conpiracy theory about a news report from the correspondent in Finland for the Swedish public service TV.',
#        'Cristiano Ronaldo’s hotels to be turned into quarantine centres in Portugal.',
#        'A video shows Italians or French people singing Madonna, Katy Perry, Britney Spears or Aya Nakamura songs on their balcony because of the lockdown measure in France and Italy.',
#        'Claims of cures for COVID-19 from multiple countries.',
#        'Irene Montero is coughing on someone during the 8M women protest.',
#        'Video shows the arrest of the first coronavirus case in Jordan.',
#        'Photo shows Palestinians’ solidarity with Italy.',
#        'Brazilian beverage company Ambev stops beer production.',
#        'Photos show animals returning to clear Venice canals.',
#        'A ship from China is anchored in Santa Marta, in Colombia.',
#        'Holding your breath for 10 seconds will tell you if you have COVID-19.',
#        'Supermarkets in Germany will only open two days a week. A screenshot shows a report from the media outlet Focus.',
#        'You can test a quality of reusable mask blowing a lighter as you wear it.',
#        'Dettol is an effective disinfectant for COVID-19.',
#        'Catalonia universities give all course credits to its students after classes being suspended.',
#        'Ireland is going into a full lockdown.',
#        'A photo claims that military vehicles are combating COVID-19 in Palermo, Italy.',
#        'CEO Resignations Are Linked To Global Conspiracy.',
#        'LGBTQ people in the US are demanding to be treated first for coronavirus.',
#        'Ireland is going into a ‘Status Red’ lockdown with the military patrolling the streets.',
#        'COVID-19 Breeds Rapidly In Toilet Paper.',
#        'A Facebook post claimed that a message from Stanford hospital gives advice to drink water every 15 minutes in order to prevent COVID-19',
#        'Audio from WhatsApp that says there are a doctor and two nurses hospitalized on the ICU in Terrassa (Barcelona)',
#        'A viral message listing false and unrelated statements about coronavirus has falsely been attributed to the United Nations International Childrenâ€™s Emergency Fund (UNICEF).',
#        'Ireland is going into a â€˜Status Redâ€™ lockdown with the military patrolling the streets.',
#        'Picture shows the Mecca totally empty.',
#        'Get the disease now to gain immunity. Infograph mimicking official information.',
#        'Citi TV interview with Korle Bu CEO discredits confirmed coronavirus cases in Ghana.',
#        'Video shows Bahrainian women running from hospitals where they were being quarantined because of COVID-19.',
#        'Elderly people are left to die in an Italian hospital near Milan.',
#        'A video purports to show body bags for virus victims in Italy.',
#        'KFC San Marino Shopping (Guayaquil, Ecuador) employee with COVID-19.',
#        'Jair Bolsonaro tested positive for COVID-19.',
#        'Policemen in China chase COVID-19 in a subway station.',
#        'Zamora has canceled Holy week due to the coronavirus.',
#        'If you can hold your breath for 10 seconds then you donâ€™t have fibrosis and therefore no infection. Picture of text in English describing the method.',
#        'Retirement benefits reduced by 50% in April in Italy.',
#        'Racist scene against Chinese people in the metro in Belgium.',
#        'Why itâ€™s dangerous to make your own hand sanitizer at home.',
#        'A viral screenshot of a story allegedly published by the BBC claiming Ghana has recorded its first confirmed coronavirus case.',
#        'Panic scene in Germany with people rushing into a supermarket.',
#        'Actor Daniel Radcliffe tested positive for COVID-19.',
#        'Galicia suspended classes because of coronavirus on 3/10/20.',
#        'Thieves in Madrid are pretending to be doctors to steal from peopleâ€™s houses.',
#        'Thieves in Palma (Spain) are pretending to be doctors to steal in peopleâ€™s houses.',
#        'Gang in Vitoria pretending to be doctors to steal from peopleâ€™s houses.',
#        'Gang in Madrid is pretending to be doctors to steal from peopleâ€™s houses.',
#        'People of the Muslim community have prohibited visiting Mecca Medina to avoid the outbreak of coronavirus, but people of Sanatan religion are playing Holi at the crematorium of Kashi Vishwanath as a pyre.',
#        'A person fainted in Caliâ€™s bus terminal because of COVID-19.',
#        'The mayor of Buga, Valle del Cauca, said: â€œI invite the people of Buga to keep calm and to live each day as if it was the last.â€\x9d',
#        'Photos purport to show the collapse of a temporary hospital in Wuhan.',
#        'Cocaine cures COVID-19.',
#        'Aaj Tak channel aired a program that said drinking alcohol or smoking weed can cure COVID-19.',
#        'Wuhan sulfur dioxide emission map shows NASA forecast.',
#        'Two Chinese nationals in Kenya have been killed after allegedly escaping from quarantine at the Nairobi Airport.',
#        'The WHO has issued an alert against buying holy colors from China',
#        'Monkeys are stealing food from a hospital in South Africa.',
#        'Photos show a well-stocked vegan shelf while other items are cleared out.',
#        'The media group Globo published a photo of the dead of the Lampedusa shipwreck as if they were COVID-19 victims.',
#        'A man is hospitalized after eating a bat.',
#        'Russia said COVID-19 is man-made.',
#        'These are seven â€œevilâ€\x9d things COVID-19 is â€œafraidâ€\x9d of.',
#        'Images show the Great Mosque of Mecca empty.',
#        'Photo shows a man wearing a â€œgovernment issued Saint Laurent hazardous materials suit.â€\x9d',
#        'The Vatican confirms Pope Francis was infected with coronavirus.',
#        'Germany gave medical protection equipment like masks to China, now itâ€™s missing in Germany.',
#        'Russia announces the closure of airspace and suspends all incoming and outgoing flights to China.',
#        'Florida man is arrested for robbery using cough as a weapon.',
#        'A man with a gas mask at a supermarket in Lugo (Galicia, Spain).',
#        'The outbreak in Taiwan is out of control. President Tsai ordered a corpse burned in front of the presidential office.',
#        'Italian Red Cross gives the recipe for making amuchina (hand sanitizer) at home.',
#        'â€œCoronavirus: Florida man arrested for robbery using cough as a weapon.â€\x9d',
#        'A man is allegedly selling medical masks for 80 denars on a bus owned by the Skopje Public Transportation Enterprise.',
#        'Indian Government and the WHO advised people not to purchase colors from China for Holi.',
#        'A crowd is waiting to greet Colombians living in Wuhan who are being flown to BogotÃ¡.',
#        'Taiwanese manufacturing is awesome. One machine can produce 2.5 million face masks per day.',
#        'Video shows an Iranian man running after a cleric claiming to be infected with the coronavirus.',
#        'Person who fainted at a subway station has COVID-19.',
#        'Many corpses from South Taiwan were sent to Taichung to burn. Taiwan has a serious community infection.',
#        'This is artwork from Wuhan.',
#        'This map shows high sulphur dioxide in Wuhan now due to the burning of corpses.',
#        'In a video, a Chinese epidemiologist says there are millions infected.',
#        'A Chinese man has been lynched because he pretended to have the coronavirus.',
#        'Rainbow shimmers behind a COVID-19 disinfectant truck in China.',
#        'Those are corpses on the street in Wuhan.',
#        'Mosques across China reopened after the coronavirus plague.',
#        'This video shows corpses on the streets of Wuhan.',
#        'A video shows the late Chinese doctor Li-wen Liangâ€™s wedding party.',
#        'An Australian couple ordered wine by drone on a Princess Cruise ship.',
#        'Data shows a massive release of sulfur dioxide gas near Wuhan.',
#        'Swarms of crows attack the streets of Wuhan.',
#        'The video of a flock of crows was shot in Wuhan, China.',
#        'SO2 map proves the massive human cremation in Wuhan.',
#        'Bus driver in China vomits blood after becoming unconscious behind the wheel.',
#        'Someone from Bosnia and Herzegovina was captured on the Diamond Princess cruiser in quarantine. After testing negative for coronavirus, he returned to BiH.',
#        'Nan-shan Zhong said there is no vegetarian getting COVID-19.',
#        'A large amount of sulfur dioxide was observed in Wuhan because up to 14,000 bodies were incinerated.',
#        'The windy diagram of sulfur dioxide emission level over Wuhan indicated massive corpses burning there.',
#        'A video shows crows are flocking to Wuhan.',
#        'Sulfur dioxide pollution in Wuhan reveals that China is burning bodies of victims.',
#        'This photo is a â€œchinese tapaâ€\x9dÂ¨from a bat.',
#        'COVID-19 was caused by 5G antennas.',
#        'Satellite images show increase in SO2 emissions around Wuhan.',
#        'Claims of cannibalism in China: People are cutting a baby in order to eat it.',
#        'A video clip shows the killing of people infected with COVID-19.',
#        'This video shows crows in the Chinese city of Xining.',
#        'Police publicly kill a coronavirus-infected woman in China.',
#        'Koreans who were on the cruise ship Diamond Princess cannot be brought back.',
#        'COVID-19 was stolen from Canada by Chinese spies and accidentally released in Wuhan.',
#        'If you have a runny nose or cough, you donâ€™t have COVID-19.',
#        'A photo shows the Biohazard Container Discovery at the American Consulate General in Wuhan.',
#        'Video shows an infected baby with a doctor.',
#        'The Dettol disinfectant label says COVID-19 was tested.',
#        'Tinospora crispa plants can treat COVID-19.',
#        'A video shows domesticated and exotic animals being sold in a wet market in Wuhan, China.',
#        'Japan has sent a 1,000-man medical team to Wuhan.',
#        'Face masks can be steamed for reuse.',
#        'Video shows pigs buried alive.',
#        'Video shows bat infestation under a tiled roof, the source of coronavirus in Hubei, China.',
#        'A video shows bats, the main source of the coronavirus, on many roofs in Hubei district.',
#        '3 preliminary studies that went viral are incorrect.',
#        'A viral video is depicting the condition in which animals are being stored in the Wuhan market.',
#        'More than 35 million people in China are now on a travel lockdown. More than 2700 have been sickened, and 81 have died.\nNothing happens without Allah’s permission and He is aware of all things.',
#        'Biohazard containers found at US consulate in Wuhan',
#        'A photo shows the newly built hospital in Wuhan.',
#        'A photo shows a new hospital in Wuhan.',
#        'Photos show part of Huoshenshan Hospital in Wuhan, built in five days.',
#        'Corpses of coronavirus victims are scattered on a street in Wuhan, China.',
#        'WHO told people to avoid sex with live animals.',
#        'WHO advises to avoid “unprotected sex” with animals.',
#        'Photo of several people lying on the ground in the middle of the street, allegedly in China.',
#        'Chinese pet owners are killing their cats and dogs by throwing them out of the window, in fear of their pets spreading the coronavirus. This comes after memos were issued by authorities for pet owners to get rid of their animals.',
#        'A person died of hematemesis in Beitou. He was then diagnosed with 2019n-Cov. Wear a mask in Taipei.',
#        'A man collapses in a staircase because of the CoV.',
#        'The WHO has recommended to avoid unprotected sex with live wild or farm animals',
#        'Death toll in Wuhan due to coronavirus reaches 10,000 people',
#        'Image shows people falling on the streets of Wuhan.',
#        'Video that shows a animal market in Wuhan.',
#        'A “Wuhan super virus” was created in a Chinese biosecurity lab and has infected more than 100,000 people in Wuhan.',
#        '10,000 people have died because of coronavirus in Wuhan.',
#        'Video footage of dead animals such as dogs, rats, bats and snakes being sold in a market in Wuhan.',
#        'Food and locations are contaminated in Australia.',
#        'Close-up of a bat soup bowl that is eaten in Wuhan, or elsewhre in China.',
#        'This video shows a woman eating a bat soup in Wuhan.',
#        'This video shows a man eating a bat soup in a restaurant in China.',
#        'Filipinos are eating a bat soup in Wuhan.',
#        '“Coronavirus in China: more than 30 million quarantined, 2.8 million infected; 112,000 dead! People falling on the streets and trains! Supermarkets without food!”',
#        'Video shows a woman eating a bat soup in Wuhan.',
#        'Close-up of a bat soup bowl eaten in Wuhan, or elsewhere in China.',
#        'The first infected person in Kazakhstan is in Almaty.',
#        'You have to wear a disposable mask with the blue side out if you are sick and the white side out if you are not.'],
#       dtype=object)
